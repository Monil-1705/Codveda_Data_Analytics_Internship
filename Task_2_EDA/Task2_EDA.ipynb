# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("../Datasets/1) iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
mean_list = []
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        mean_list.append(df[col].mean())
        print(f"Mean of {col} is : {df[col].mean()}")
# Out:
# Mean of sepal_length is : 5.843333333333334
# Mean of sepal_width is : 3.0540000000000003
# Mean of petal_length is : 3.758666666666666
# Mean of petal_width is : 1.1986666666666668

# %%
mean_list
# Out:
# [5.843333333333334, 3.0540000000000003, 3.758666666666666, 1.1986666666666668]

# %%
median_list = []
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        median_list.append(df[col].median())
        print(f"Median of {col} is : {df[col].median()}")
# Out:
# Median of sepal_length is : 5.8
# Median of sepal_width is : 3.0
# Median of petal_length is : 4.35
# Median of petal_width is : 1.3

# %%
median_list
# Out:
# [5.8, 3.0, 4.35, 1.3]

# %%
mode_list = []
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        mode_list.append(df[col].mode())
        print(f"Mode of {col} is : {df[col].mode()[0]}")
# Out:
# Mode of sepal_length is : 5.0
# Mode of sepal_width is : 3.0
# Mode of petal_length is : 1.5
# Mode of petal_width is : 0.2

# %%
stdev_list = []
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        stdev_list.append(df[col].std())
        print(f"Standard Deviation of {col} is : {df[col].std()}")
# Out:
# Standard Deviation of sepal_length is : 0.8280661279778629
# Standard Deviation of sepal_width is : 0.4335943113621737
# Standard Deviation of petal_length is : 1.7644204199522617
# Standard Deviation of petal_width is : 0.7631607417008414

# %% [markdown]
# # Visualizations :

# %% [markdown]
# ### Histograms

# %%
sns.histplot(data=df, x='sepal_length', color="blue", bins=10)
plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(data=df, x="sepal_width", color='green', bins=10)
plt.title("Histogram of Sepal Width")
plt.xlabel("Sepal Width")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(data=df, x='petal_length', color='yellow', bins=10)
plt.title("Histogram of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %%
# fig4, ax4 = plt.subplots()
# ax4.hist(x=df['petal_width'], color='orange')
# ax4.set(xlabel='sepeal_width', ylabel='Frequency', title="Histogram of Sepal Width")
# plt.show()

sns.histplot(data=df, x='petal_width', color='orange')
plt.title("Histogram of Petal Width")
plt.xlabel("Petal Width")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Box Plots

# %%
sns.boxplot(data=df, y='sepal_length', color="blue")
plt.title("Box plot of Sepal Length")
plt.show()

# %%
sns.boxplot(data=df, y='sepal_width', color="green")
plt.title("Box plot of Sepal Width")
plt.show()

# %%
sns.boxplot(data=df, y='petal_length', color='yellow')
plt.title("Box plot fo Petal Length")
plt.show()

# %%
sns.boxplot(data=df, y='petal_width', color='orange')
plt.title("Box plot of Petal Width")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue="species", style="species")
plt.title("Scatter Plot of Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
sns.scatterplot(data=df, x='sepal_length', y='petal_length', hue="species", style="species")
plt.title("Scatter Plot of Sepal Length vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# %%
sns.scatterplot(data=df, x='sepal_length', y='petal_width', hue="species", style="species")
plt.title("Scatter Plot of Sepal Length vs Petal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Width")
plt.show()

# %%
sns.scatterplot(data=df, x='sepal_width', y='petal_length', hue="species", style="species")
plt.title("Scatter Plot of Sepal Width vs Petal Length")
plt.xlabel("Sepal Width")
plt.ylabel("Petal Length")
plt.show()

# %%
sns.scatterplot(data=df, x='sepal_width', y='petal_width', hue="species", style="species")
plt.title("Scatter Plot of Sepal Width vs Petal Width")
plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.show()

# %%
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue="species", style="species")
plt.title("Scatter Plot of Petal Length vs Petal Width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
corr_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(data=corr_matrix, annot=True, cmap="Blues")
plt.title("Correlation Heatmap")
plt.show()
